# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/Module 3' -r '/content/'

# %%
# !pip install selfcheckgpt
# Out:
# Collecting selfcheckgpt
#   Downloading selfcheckgpt-0.1.7.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.35 in /usr/local/lib/python3.10/dist-packages (from selfcheckgpt) (4.38.2)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from selfcheckgpt) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from selfcheckgpt) (1.25.2)
# Collecting bert_score (from selfcheckgpt)
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from selfcheckgpt) (3.7.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from selfcheckgpt) (3.8.1)
# Collecting openai (from selfcheckgpt)
#   Downloading openai-1.14.2-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 54.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 69.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.8 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.12->selfcheckgpt)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->selfcheckgpt) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.12->selfcheckgpt)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.3 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35->selfcheckgpt) (4.66.2)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score->selfcheckgpt) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score->selfcheckgpt) (3.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->selfcheckgpt) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->selfcheckgpt) (1.3.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->selfcheckgpt) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->selfcheckgpt) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai->selfcheckgpt)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai->selfcheckgpt) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->selfcheckgpt) (1.3.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (6.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->selfcheckgpt) (3.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->selfcheckgpt) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->selfcheckgpt) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->selfcheckgpt) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai->selfcheckgpt)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 12.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai->selfcheckgpt)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score->selfcheckgpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score->selfcheckgpt) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->selfcheckgpt) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->selfcheckgpt) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35->selfcheckgpt) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35->selfcheckgpt) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->selfcheckgpt) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->selfcheckgpt) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy->selfcheckgpt) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->selfcheckgpt) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score->selfcheckgpt) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score->selfcheckgpt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score->selfcheckgpt) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score->selfcheckgpt) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score->selfcheckgpt) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score->selfcheckgpt) (3.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12->selfcheckgpt) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.1->bert_score->selfcheckgpt) (1.16.0)
# Building wheels for collected packages: selfcheckgpt
#   Building wheel for selfcheckgpt (setup.py) ... done
#   Created wheel for selfcheckgpt: filename=selfcheckgpt-0.1.7-py3-none-any.whl size=14770 sha256=cf83d685c71d68d728afc708f530cbf954a96d8abf5a9f958b2d6d4c7af7988a
#   Stored in directory: /root/.cache/pip/wheels/15/8b/94/3ce98f2b5e3a92ae685264263a22f3050049743eb773bda37b
# Successfully built selfcheckgpt
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, h11, nvidia-cusparse-cu12, nvidia-cudnn-cu12, httpcore, nvidia-cusolver-cu12, httpx, openai, bert_score, selfcheckgpt
# Successfully installed bert_score-0.3.13 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 openai-1.14.2 selfcheckgpt-0.1.7

# %%
NGROK_TOKEN = '2dKJq0uCNWj1qTgb54rVGxYb2zi_36ENdC4s3ZLQEgXcFwcNd'

# !pip install flask
# !pip install pyngrok

from pyngrok import ngrok, conf
conf.get_default().auth_token = NGROK_TOKEN
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask) (2.1.5)
# Collecting pyngrok
#   Downloading pyngrok-7.1.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.5

# %%
# NGROK_TOKEN = '2dKJq0uCNWj1qTgb54rVGxYb2zi_36ENdC4s3ZLQEgXcFwcNd'

# !pip install flask
# !pip install pyngrok

# from pyngrok import ngrok, conf
# conf.get_default().auth_token = NGROK_TOKEN

# %%
# !pip install --upgrade flask-ngrok
# !pip install pyngrok==4.1.1
# !ngrok authtoken '2dKJq0uCNWj1qTgb54rVGxYb2zi_36ENdC4s3ZLQEgXcFwcNd'

# %%
import torch
from selfcheckgpt.modeling_mqag import MQAG

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

mqag_model = MQAG(
    g1_model_type='race', # race (more abstractive), squad (more extractive)
    device=device
)
# Out:
# cuda
# MQAG (race) initialized to cuda

# %%
# %cd '/content/Module 3/'
# Out:
# /content/Module 3

# %%
import numpy as np

def generate_questions_answers(context):
  questions = mqag_model.generate(context=context, do_sample=True, num_questions=10)
  final_set = []
  for i, question_item in enumerate(questions):
      question = question_item['question']
      options = question_item['options']

      single_question = [{'question': question, 'options': options}]
      probs = mqag_model.answer(questions=single_question, context=context)
      correct_answer = options[np.argmax(probs)]

      final_set.append({'question': question, 'options': options, 'answer': correct_answer})

  return final_set

# %%
from flask import Flask, render_template, request, redirect, url_for , jsonify
import json
# from flask_ngrok import run_with_ngrok
from pyngrok import ngrok
import requests
from datetime import datetime


app = Flask(__name__)
# run_with_ngrok(app)


global answers
global quiz_data_v2
global questionText
questionText = ""


with open("details.json", "r") as jf:
    data = json.load(jf)
    users = data["login"]

def get_current_date():
    response = requests.get('http://worldtimeapi.org/api/ip')
    if response.status_code == 200:
        current_time = response.json()['datetime']
        return datetime.strptime(current_time, '%Y-%m-%dT%H:%M:%S.%f%z').strftime('%Y-%m-%d')
    else:
        return datetime.now().strftime('%Y-%m-%d')  # Fallback to current date if online API fails


@app.route('/', methods=['GET', 'POST'])
def login():
    if request.method == 'POST':
        # Retrieve form data
        email = request.form.get('login-email')
        password = request.form.get('login-password')

        if email in users.keys() and users[email]==password:
            return redirect(url_for('generate_qna'))

    return render_template('auth.html')


@app.route('/signup', methods=['GET', 'POST'])
def signup():
    if request.method == 'POST':
        # Retrieve form data
        email = request.form.get('signup-email')
        password = request.form.get('signup-password')
        password2 = request.form.get('confirm-signup-password')

        # Perform validation or other actions with the form data
        with open("details.json", "w") as jfk:
            users[email] = password
            json.dump(users, jfk)

        # Print form data (for demonstration purposes)
        print(f'Email: {email}, Password: {password} ,  password2 : { password2}')

        # Add your logic for user registration or other actions
        return redirect(url_for('login'))

    return render_template('auth.html')




@app.route('/create_post' , methods=['GET', 'POST'] )
def create_post():
    # Additional logic for generating Q&A or render a template
     if request.method == 'POST':
            # Retrieve form data
        new_post = request.form.get('post-input')


        # Perform validation or other actions with the form data

        # Print form data (for demonstration purposes)
        print(f'new_post: {new_post}')
        return redirect(url_for('forum'))




@app.route('/generate_qna' , methods=['GET', 'POST'])
def generate_qna():
    # Additional logic for generating Q&A or render a template
    question_data = [
    {"subject": "Math", "num_questions": 10},
    {"subject": "Physics", "num_questions": 10},
    {"subject": "Python", "num_questions": 10},
    # Add more data as needed
]

    return render_template('generate_qna.html' , questions=question_data)


@app.route('/answer_evaluation')
def answer_evaluation():

    subj_data = data["scores"]
    subjects_data = [
        {"subject": list(subj_data.keys())[0], "score": subj_data[list(subj_data.keys())[0]]},
        {"subject": list(subj_data.keys())[1], "score": subj_data[list(subj_data.keys())[1]]},
        {"subject": list(subj_data.keys())[2], "score": subj_data[list(subj_data.keys())[2]]},
    ]

    return render_template('answer_evaluation.html', subjects_data=subjects_data)
    # Additional logic for generating Q&A or render a template



@app.route('/forum')
def forum():
    # Additional logic for generating Q&A or render a template
    post_data = [
        {
            'title' : "Golanginya",
            'content'  : "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Consequat aliquet maecenas ut sit nulla"
        },
        {
            'title' : "Golanginya",
            'content'  : "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Consequat aliquet maecenas ut sit nulla"
        },
        {
            'title' : "Golanginya",
            'content'  : "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Consequat aliquet maecenas ut sit nulla"
        }
    ]
    return render_template('forum.html' ,post_data=post_data )


@app.route('/quiz' , methods=['GET', 'POST'])
def quiz():
    global answers
    global quiz_data_v2
    global questionText
    quiz_data = [

    {
        "question": "For Fiscal year 2021, what was your total GhG Carbon Emission for all scopes?",
        "options": [
            "Scope 1 - Determine environmental impact levels.",
            "Scope 2 - Reduce carbon footprints.",
            "Scope 3 - Enhance environmental impacts on a larger scale.",
            "I do not know the answer to this question.",
        ],
    },
    {
        "question": "Another question?",
        "options": [
            "Option 1",
            "Option 2",
            "Option 3",
            "I do not know the answer to this question.",
        ],
    },


    # Add more questions and answers as needed
    ]
    if request.method == 'POST':
        print("post method ************")
        questionText = request.form.get('questionText')
        print(f"Launching quiz for subject: {questionText}")
        quiz_data = generate_questions_answers(questionText.replace('\n', ' '))

        quiz_data_v2 = []
        answers = []
        for item in quiz_data:
            # d = ast.literal_eval(item)
            js_data = {
                "question": item['question'],
                "answers": item['options']
            }
            quiz_data_v2.append(js_data)
            answers.append(item['answer'])
        print(quiz_data_v2)
        print("Answers:", answers)

        # return redirect(url_for('quiz'))
        render_template('quiz.html' , quiz_data=quiz_data_v2)

    return render_template('quiz.html', quiz_data=quiz_data_v2)


@app.route('/quiz/response', methods=['POST'])
def quiz_response():
    global quiz_data_v2
    global answers

    if request.method == 'POST':
        # Retrieve the selected answers from the form
        selected_answers = []

        for question in quiz_data_v2:
            selected_answers.append(request.form.get(f'selected-answer-{question["question"]}'))


        # You can now process the selected answers as needed
        # For example, you might want to store them in a database or perform some analysis

        # For now, let's just print the selected answers
        print("Selected Answers:", selected_answers)
        score = 0
        quiz_data_ans = []

        for i in range(len(selected_answers)):
          quiz_data_ans.append({'question': quiz_data_v2[i]['question'], 'answer':answers[i]})
          if selected_answers[i]==answers[i]:
            score += 10


        result = "Fail" if score<50 else "Pass"


        # quiz_data_ans = [

        #         {
        #             "question": "For Fiscal year 2021, what was your total GhG Carbon Emission for all scopes?",
        #         "answer": "Scope 3 - Enhance environmental impacts on a larger scale."
        #     },
        #     {
        #         "question": "Another question?",
        #         "answer": "Option 3"
        #     },

        # ]

        # You can redirect to a different page or render a new template
        return render_template('QuizResult.html', result=result , score=score , quiz_data_ans=quiz_data_ans )
        # You might want to render a response or redirect to another page
    return render_template('quiz.html', quiz_data=quiz_data_v2)

@app.route('/discussion', methods=['GET', 'POST'])
def discussion():
    if request.method == 'POST':
        # Retrieve form data
        new_comment = request.form.get('comment-input')

        # Perform any additional actions with the form data

        # Print form data (for demonstration purposes)
        print(f'New Comment: {new_comment}')
        return redirect(url_for('discussion'))

    return render_template('discussion.html')

@app.route('/expert_support', methods=['GET', 'POST'])
def get_answer_from_chatgpt():
    if request.method == 'POST':
        question = request.json.get('question')  # Accessing JSON data instead of form data
        try:
            # Simulating the response from OpenAI API
            # You can replace this section with your actual API call
            response = {'answers': [{'text': 'Sorry, an error occurred while processing your request.'}]}
            return jsonify({'answer': response['answers'][0]['text']})
        except Exception as e:
            print("Error fetching answer:", e)
            return jsonify({'error': "Sorry, an unexpected error occurred. Please try again later."}), 500
    return render_template('expert_support.html')




@app.route('/logout')
def logout():
    # Additional logic for generating Q&A or render a template
    return redirect(url_for('login'))


ngrok_tunnel = ngrok.connect(5000)
print(ngrok_tunnel)
# print('Running at:', ngrok_tunnel.public_url)

if __name__ == '__main__':
    app.run(port=5000)
# Out:
# NgrokTunnel: "https://f45e-35-247-142-223.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:39] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:39] "GET /static/js/auth.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:40] "GET /static/css/auth.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:41] "GET /static/Assets/LLEX.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:44] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:48] "POST / HTTP/1.1" 302 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:48] "GET /generate_qna HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:49] "GET /static/css/generate_qna.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:04:53] "GET /expert_support HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:05:13] "GET /discussion HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:05:27] "GET /answer_evaluation HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:05:28] "GET /static/css/answer_evaluation.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:05:30] "GET /generate_qna HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [22/Mar/2024 10:05:31] "GET /static/css/generate_qna.css HTTP/1.1" 304 -
